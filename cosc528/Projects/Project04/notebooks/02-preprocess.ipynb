# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
train_file = '../data/processed/train.csv'

# %%
train = pd.read_csv(train_file)

# %%
pred_cols = train.columns[:-1]

# %%
scaler = StandardScaler().fit(train[pred_cols])
# Out:
# /Users/jrpowers-luhn/miniconda3/envs/cs528/lib/python3.6/site-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)

# %%
train[pred_cols] = scaler.transform(train[pred_cols])
# Out:
# /Users/jrpowers-luhn/miniconda3/envs/cs528/lib/python3.6/site-packages/ipykernel/__main__.py:1: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   if __name__ == '__main__':

# %%
train.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0       -0.030846          -0.161594      -0.368151     -0.051823
# 1       -0.345227          -0.161594      -0.567014     -0.051823
# 2       -0.345227          -0.161594       0.109119     -0.051823
# 3       -0.250912          -0.161594      -0.507355      0.036116
# 4       -0.345227          -0.161594      -0.567014     -0.051823
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0       0.160600        0.003225         -0.029695           -0.278798
# 1      -0.447050       -0.335323         -0.278896           -0.278798
# 2       0.069453       -0.335323         -0.278896           -0.278798
# 3      -0.355902       -0.233759         -0.278896           -0.278798
# 4      -0.295137       -0.335323         -0.278896           -0.278798
#
#    word_freq_order  word_freq_mail  ...   char_freq_;  char_freq_(  \
# 0         0.375980       -0.053646  ...     -0.155187    -0.196410
# ...
